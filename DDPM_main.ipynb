# %% [markdown]
# [![Github](https://img.shields.io/github/stars/labmlai/annotated_deep_learning_paper_implementations?style=social)](https://github.com/labmlai/annotated_deep_learning_paper_implementations)
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/labmlai/annotated_deep_learning_paper_implementations/blob/master/labml_nn/diffusion/ddpm/experiment.ipynb)
#
# ## [Denoising Diffusion Probabilistic Models (DDPM)](https://nn.labml.ai/diffusion/ddpm/index.html)
#
# This notebook trains a DDPM based model on MNIST digits dataset.

# %% [markdown]
# ### Install the packages

# %%
# !pip install labml-nn --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.3/266.3 kB 18.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 443.9/443.9 kB 27.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.0/131.0 kB 6.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 50.8 MB/s eta 0:00:00
#   Building wheel for fairscale (pyproject.toml) ... done

# %% [markdown]
# ### Imports

# %%
import torch
import torch.nn as nn

from labml import experiment
from labml.configs import option
from labml_nn.diffusion.ddpm.experiment import Configs

# %% [markdown]
# ### Create an experiment

# %%
experiment.create(name="diffuse", writers={'screen'})

# %% [markdown]
# ### Configurations

# %%
configs = Configs()

# %% [markdown]
# Set experiment configurations and assign a configurations dictionary to override configurations

# %%
experiment.configs(configs, {
    'dataset': 'MNIST',
    'image_channels': 1,
    'epochs': 5,
})
# Out:
# <pre style="overflow-x: scroll;"></pre>

# %% [markdown]
# Initializ

# %%
configs.init()
# Out:
# <pre style="overflow-x: scroll;">Prepare device.device...
#   Prepare device.device_info<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	79.78ms</span>
# Prepare device.device<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	84.44ms</span>
# Prepare dataset<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	29,763.77ms</span>
# </pre>
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to /content/data/MNISTDataset/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9.91M/9.91M [00:11<00:00, 901kB/s]
# Extracting /content/data/MNISTDataset/raw/train-images-idx3-ubyte.gz to /content/data/MNISTDataset/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to /content/data/MNISTDataset/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 64.2kB/s]
# Extracting /content/data/MNISTDataset/raw/train-labels-idx1-ubyte.gz to /content/data/MNISTDataset/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to /content/data/MNISTDataset/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1.65M/1.65M [00:06<00:00, 241kB/s]
# Extracting /content/data/MNISTDataset/raw/t10k-images-idx3-ubyte.gz to /content/data/MNISTDataset/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to /content/data/MNISTDataset/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 3.11MB/s]
# Extracting /content/data/MNISTDataset/raw/t10k-labels-idx1-ubyte.gz to /content/data/MNISTDataset/raw

# %% [markdown]
# Set PyTorch models for loading and saving

# %%
experiment.add_pytorch_models({'eps_model': configs.eps_model})

# %% [markdown]
# ### Start the experiment and run the training loop.

# %%
# Start the experiment
with experiment.start():
    configs.run()
# Out:
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">3b319108b2fb11efb1130242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">     938:  </span></strong>Train:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB">   409,174ms  </span>Sample:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB">  57,223ms  </span> loss: <span style="color: #C5C1B4">0.022160</span>  <span style="color: #208FFB">466,397ms</span><span style="color: #D160C4">  0:07m/  0:31m  </span>
# <strong><span style="color: #DDB62B">   1,876:  </span></strong>Train:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB">   412,549ms  </span>Sample:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB">  57,038ms  </span> loss: <span style="color: #C5C1B4">0.015531</span>  <span style="color: #208FFB">473,316ms</span><span style="color: #D160C4">  0:15m/  0:23m  </span>
# <strong><span style="color: #DDB62B">   2,814:  </span></strong>Train:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB">   412,509ms  </span>Sample:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB">  57,016ms  </span> loss: <span style="color: #C5C1B4">0.013007</span>  <span style="color: #208FFB">475,928ms</span><span style="color: #D160C4">  0:23m/  0:15m  </span>
# <strong><span style="color: #DDB62B">   3,752:  </span></strong>Train:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB">   414,125ms  </span>Sample:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB">  57,014ms  </span> loss: <span style="color: #C5C1B4">0.008219</span>  <span style="color: #208FFB">477,661ms</span><span style="color: #D160C4">  0:31m/  0:08m  </span>
# <strong><span style="color: #DDB62B">   4,690:  </span></strong>Train:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB">   415,452ms  </span>Sample:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB">  57,058ms  </span> loss: <span style="color: #C5C1B4">0.010323</span>  <span style="color: #208FFB">479,435ms</span><span style="color: #D160C4">  0:39m/  0:00m  </span></pre>
